# %%
# !pip install tensorflow==2.4.0

# %%
# !pip install --upgrade tensorflow

# %%
# !python -m pip install -U pillow
# !python -m pip install -U albumentations
# !python -m pip install -U segmentation-models
# !python -m pip install azureml-sdk[notebooks]
# !pip install azureml-contrib-services
# !pip install opencv-python

# %%
import numpy as np
import os, glob, re, tempfile
import requests
import json
import cv2
import matplotlib.pyplot as plt
import azureml.core
from azureml.core import Workspace, Datastore, Dataset, Run, Model, Webservice, Environment
from azureml.core.webservice import AciWebservice
from azureml.core.model import InferenceConfig
from azureml.core.environment import CondaDependencies
import albumentations as A
from albumentations import Compose
from skimage.transform import resize
import azureml.dataprep as dprep
#from azureml.dataprep.fuse.dprepfuse import mount
import tensorflow as tf
from tensorflow import keras
import segmentation_models as sm
sm.set_framework('tf.keras')
# Out:
# Segmentation Models: using `keras` framework.

# %%
from azureml.core import Workspace
ws = Workspace.from_config(path="config.json")
print(ws.name, ws.location, ws.resource_group, sep='\t')
# Out:
# WS_P8_JCROSELLO	westeurope	cloud-shell-storage-westeurope

# %%
# see workspace details
ws.get_details()
# Out:
# {'id': '/subscriptions/75c51acd-24dc-4674-9a83-dd6319951bf8/resourceGroups/cloud-shell-storage-westeurope/providers/Microsoft.MachineLearningServices/workspaces/WS_P8_JCROSELLO',
#  'name': 'WS_P8_JCROSELLO',
#  'identity': {'principal_id': '4a84ea2e-bfd3-4f0e-bb7c-3c7542a71cf4',
#   'tenant_id': '31f99866-f9ca-40e6-bc44-16e162aed2f1',
#   'type': 'SystemAssigned'},
#  'location': 'westeurope',
#  'type': 'Microsoft.MachineLearningServices/workspaces',
#  'tags': {},
#  'sku': 'Basic',
#  'workspaceid': '90b29487-d73e-4a40-bf7b-a1a479453efc',
#  'sdkTelemetryAppInsightsKey': '6d7b2b55-6d18-4126-a3ee-251f78cfa6e5',
#  'description': '',
#  'friendlyName': 'WS_P8_JCROSELLO',
#  'creationTime': '2021-05-10T08:30:22.1286261+00:00',
#  'containerRegistry': '/subscriptions/75c51acd-24dc-4674-9a83-dd6319951bf8/resourceGroups/cloud-shell-storage-westeurope/providers/Microsoft.ContainerRegistry/registries/90b29487d73e4a40bf7ba1a479453efc',
#  'keyVault': '/subscriptions/75c51acd-24dc-4674-9a83-dd6319951bf8/resourcegroups/cloud-shell-storage-westeurope/providers/microsoft.keyvault/vaults/wsp8jcrosello8863586183',
#  'applicationInsights': '/subscriptions/75c51acd-24dc-4674-9a83-dd6319951bf8/resourcegroups/cloud-shell-storage-westeurope/providers/microsoft.insights/components/wsp8jcrosello1472955636',
#  'storageAccount': '/subscriptions/75c51acd-24dc-4674-9a83-dd6319951bf8/resourcegroups/cloud-shell-storage-westeurope/providers/microsoft.storage/storageaccounts/wsp8jcrosello2206822560',
#  'hbiWorkspace': False,
#  'allowPublicAccessWhenBehindVnet': False,
#  'provisioningState': 'Succeeded',
#  'imageBuildCompute': '',
#  'discoveryUrl': 'https://westeurope.api.azureml.ms/discovery',
#  'notebookInfo': {'fqdn': 'ml-wsp8jcrosell-westeurope-90b29487-d73e-4a40-bf7b-a1a479453efc.notebooks.azure.net',
#   'resource_id': 'aa70dca7d737408d8a62359f0d5d6992'}}

# %%
# %%writefile script1.py


# -*- coding: utf-8 -*-
# +
import numpy as np
import os, glob, re, tempfile
import requests, json
import cv2
import albumentations as A
import tensorflow as tf
from tensorflow import keras
from albumentations import Compose
from albumentations import ToFloat
import segmentation_models as sm
sm.set_framework('tf.keras')
from azureml.core.model import Model
from azureml.core import Workspace, Datastore, Dataset
from skimage.transform import resize
import PIL
from io import BytesIO
from PIL import Image
from numpy import asarray
from azureml.contrib.services.aml_request import AMLRequest, rawhttp
from azureml.contrib.services.aml_response import AMLResponse


def DataPrepImage(rawimage):
    Def=256
    img = rawimage.resize((Def,Def), resample=PIL.Image.BILINEAR)
    img = (np.array(img)/255).reshape(-1,Def,Def,1)
    return img

# Chargement du modèle sauvegardé
def init():
    global model
    global DIM
    global BACKBONE
     
    model = Model.get_model_path(model_name='model8lp3')

    
    # Model
    ARCHITECTURE = 'Unet'
    BACKBONE = 'resnet34'
    BATCH_SIZE = 8
    LR = 0.001
    EPOCHS = 5
    DIM = (256, 256)
    N_CLASSES = 8
    N_CHANNELS = 3
    ACTIVATION = 'softmax'
    LOSS = 'DICE' 
    CLASS_WEIGHTS = None


    #metrics = [sm.metrics.IOUScore(class_weights=CLASS_WEIGHTS), sm.metrics.FScore(class_weights=CLASS_WEIGHTS)]
    metrics = [sm.metrics.IOUScore(threshold=0.5), sm.metrics.FScore(threshold=0.5)]
    opt = keras.optimizers.Adam(learning_rate=LR)
    
    # Segmentation models losses can be combined together by '+' and scaled by integer or float factor
    #loss = sm.losses.DiceLoss(class_weights=CLASS_WEIGHTS)
    loss = tf.keras.losses.CategoricalCrossentropy()
    #model = sm.Unet(BACKBONE, encoder_weights='imagenet', encoder_freeze=False, input_shape=(256, 256, 3), classes=N_CLASSES, activation=ACTIVATION)
    #model.compile(optimizer=opt, loss=loss, metrics=metrics)   
    model = sm.Unet(input_shape=(256,256,3), classes=N_CLASSES, activation=ACTIVATION)
    model.compile(optimizer=opt, loss=loss, metrics=metrics)
     
    # load models
    #model_path =  './model81.h5'
    #model_path = os.path.join(os.getenv('AZUREML_MODEL_DIR'), './model8p1.h5')    
    #model = Model.get_model_path(model_name='model8p1') 
       
        
@rawhttp
def run(request):
    print("This is run()")
    
    if request.method == 'GET':
        # For this example, just return the URL for GETs.
        respBody = str.encode(request.full_path)
        return AMLResponse(respBody, 200)
    elif request.method == 'POST':
        # preprocessing function
        def get_preprocessing(preprocessing_fn):   
            _transform = [
                A.Lambda(image=preprocessing_fn),
            ]
            return A.Compose(_transform)
        
        file_bytes = request.files["image"]
        image = Image.open(file_bytes).convert('RGB')
        # For a real-world solution, you would load the data from reqBody
        # and send it to the model. Then return the response.
        #Conversion image to array
        data = asarray(image)
        #resize image
        temp_raw = resize(data, (256, 256))
        # Predict
        aug = Compose([
            #A.HorizontalFlip(p=0.5),              
            #A.OpticalDistortion(distort_limit=2, shift_limit=0.9, p=0.5),
            A.RandomContrast(limit=0.5, p=1)
            ]
        )
        augmented = aug(image=temp_raw)
        preprocess_input = sm.get_preprocessing(BACKBONE)
        preprocessing=get_preprocessing(preprocess_input)
        sample = preprocessing(image=augmented['image'])


        print('>>>>>>>>>>>>>>>>>>>>>> 5')

        prediction = model.predict(sample['image'].reshape(1, *sample['image'].shape))
        #prediction = model.predict(temp_raw)

        print('>>>>>>>>>>>>>>>>>>>>>> 6')

        prediction_array = prediction[0].argmax(2)        
        
        
        # For demonstration purposes, this example just returns the size of the image as the response..
        return AMLResponse(json.dumps(prediction_array.tolist()), 200)
    else:
        return AMLResponse("bad request", 500)
# -
# Out:
# Overwriting script1.py

# %%
from azureml.core.model import Model
model8lp3 = Model(ws, 'model8lp3', version=1)

# %%
model = model8lp3
model
# Out:
# Model(workspace=Workspace.create(name='WS_P8_JCROSELLO', subscription_id='75c51acd-24dc-4674-9a83-dd6319951bf8', resource_group='cloud-shell-storage-westeurope'), name=model8lp3, id=model8lp3:1, version=1, tags={}, properties={})

# %%
# Create the environment
env_selected = Environment(name="env_selected")
conda_dep = CondaDependencies()

# Define the packages needed by the model and scripts
conda_dep.add_conda_package("tensorflow")
#conda_dep.add_conda_package("numpy")
#conda_dep.add_conda_package("scikit-learn")
#conda_dep.add_conda_package("pandas")

# You must list azureml-defaults as a pip dependency
#conda_dep.add_conda_package("pip")
#conda_dep.remove_pip_package('horovod')
#conda_dep.remove_pip_package('cmake')
conda_dep.add_pip_package("segmentation_models")
conda_dep.add_pip_package("pillow")
conda_dep.add_pip_package("opencv-python")
conda_dep.add_pip_package("albumentations")
conda_dep.add_pip_package("azureml-sdk[notebooks]")
with open("env_selected.yml","w") as f:
    f.write(conda_dep.serialize_to_string())
# Adds dependencies to PythonSection of env_selected
env_selected.python.conda_dependencies=conda_dep
env_selected
# Out:
# {
#     "databricks": {
#         "eggLibraries": [],
#         "jarLibraries": [],
#         "mavenLibraries": [],
#         "pypiLibraries": [],
#         "rcranLibraries": []
#     },
#     "docker": {
#         "arguments": [],
#         "baseDockerfile": null,
#         "baseImage": "mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20210513.v1",
#         "baseImageRegistry": {
#             "address": null,
#             "password": null,
#             "registryIdentity": null,
#             "username": null
#         },
#         "enabled": false,
#         "platform": {
#             "architecture": "amd64",
#             "os": "Linux"
#         },
#         "sharedVolumes": true,
#         "shmSize": "2g"
#     },
#     "environmentVariables": {
#         "EXAMPLE_ENV_VAR": "EXAMPLE_VALUE"
#     },
#     "inferencingStackVersion": null,
#     "name": "env_selected",
#     "python": {
#         "baseCondaEnvironment": null,
#         "condaDependencies": {
#             "channels": [
#                 "anaconda",
#                 "conda-forge"
#             ],
#             "dependencies": [
#                 "python=3.6.2",
#                 {
#                     "pip": [
#                         "azureml-defaults",
#                         "segmentation_models",
#                         "pillow",
#                         "opencv-python",
#                         "albumentations",
#                         "azureml-sdk[notebooks]"
#                     ]
#                 },
#                 "tensorflow"
#             ],
#             "name": "project_environment"
#         },
#         "condaDependenciesFile": null,
#         "interpreterPath": "python",
#         "userManagedDependencies": false
#     },
#     "r": null,
#     "spark": {
#         "packages": [],
#         "precachePackages": true,
#         "repositories": []
#     },
#     "version": null
# }

# %% [markdown]
# ## Déploiement web service API

# %%
inference_config = InferenceConfig(entry_script="./script1.py", environment=env_selected)
deployment_config = AciWebservice.deploy_configuration(cpu_cores=3, memory_gb=15)

# %%
#service_name = "predictp8jcrosello2"
#service = Model.deploy(ws, service_name, Model.list(ws, "model8"), inference_config, deployment_config)
#service.wait_for_deployment(True)

# Define the model, inference, & deployment configuration and web service name and location to deploy
service = Model.deploy(
    workspace = ws,
    name = "predictp8jcrosello1",
    models = [model],
    inference_config = inference_config,
    deployment_config = deployment_config)

service.wait_for_deployment(show_output=True)

print(service.state)
# Out:
# Tips: You can try get_logs(): https://aka.ms/debugimage#dockerlog or local deployment: https://aka.ms/debugimage#debug-locally to debug if deployment takes longer than 10 minutes.
# Running
# 2021-06-11 16:37:08+02:00 Creating Container Registry if not exists.
# 2021-06-11 16:37:09+02:00 Use the existing image.
# 2021-06-11 16:37:10+02:00 Generating deployment configuration.
# 2021-06-11 16:37:11+02:00 Submitting deployment to compute..
# 2021-06-11 16:37:18+02:00 Checking the status of deployment predictp8jcrosello1..
# 2021-06-11 16:40:24+02:00 Checking the status of inference endpoint predictp8jcrosello1.
# Succeeded
# ACI service creation operation finished, operation "Succeeded"
# Healthy

# %%
print(service.get_logs())
# Out:
# 2021-06-11T14:40:19,486780612+00:00 - rsyslog/run
# 2021-06-11T14:40:19,488432119+00:00 - iot-server/run
# 2021-06-11T14:40:19,489556624+00:00 - gunicorn/run
# File not found: /var/azureml-app/.
# Starting HTTP server
# 2021-06-11T14:40:19,490221827+00:00 - nginx/run
# EdgeHubConnectionString and IOTEDGE_IOTHUBHOSTNAME are not set. Exiting...
# 2021-06-11T14:40:19,586588342+00:00 - iot-server/finish 1 0
# 2021-06-11T14:40:19,588032749+00:00 - Exit code 1 is normal. Not restarting iot-server.
# Starting gunicorn 20.1.0
# Listening at: http://127.0.0.1:31311 (13)
# Using worker: sync
# worker timeout is set to 300
# Booting worker with pid: 41
# SPARK_HOME not set. Skipping PySpark Initialization.
# Segmentation Models: using `tf.keras` framework.
# Initializing logger
# 2021-06-11 14:40:24,381 | root | INFO | Starting up app insights client
# logging socket was found. logging is available.
# logging socket was found. logging is available.
# 2021-06-11 14:40:24,381 | root | INFO | Starting up request id generator
# 2021-06-11 14:40:24,382 | root | INFO | Starting up app insight hooks
# 2021-06-11 14:40:24,382 | root | INFO | Invoking user's init function
# 2021-06-11 14:40:24.405529: I tensorflow/core/platform/cpu_feature_guard.cc:145] This TensorFlow binary is optimized with Intel(R) MKL-DNN to use the following CPU instructions in performance critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in non-MKL-DNN operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-06-11 14:40:24.415484: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2294685000 Hz
# 2021-06-11 14:40:24.415996: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x555849ac4090 executing computations on platform Host. Devices:
# 2021-06-11 14:40:24.416044: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): Host, Default Version
# 2021-06-11 14:40:24.416709: I tensorflow/core/common_runtime/process_util.cc:115] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# Downloading data from
# no request id,Downloading data from
#
# https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# no request id,https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
#
#     8192/58889256 [..............................]
# no request id,    8192/58889256 [..............................]
#
#  - ETA: 1s
# no request id, - ETA: 1s
#
#
# no request id,
#
#   630784/58889256 [..............................]
# no request id,  630784/58889256 [..............................]
#
#  - ETA: 4s
# no request id, - ETA: 4s
#
#
# no request id,
#
#  1204224/58889256 [..............................]
# no request id, 1204224/58889256 [..............................]
#
#  - ETA: 4s
# no request id, - ETA: 4s
#
#
# no request id,
#
#  1777664/58889256 [..............................]
# no request id, 1777664/58889256 [..............................]
#
#  - ETA: 5s
# no request id, - ETA: 5s
#
#
# no request id,
#
#  2531328/58889256 [>.............................]
# no request id, 2531328/58889256 [>.............................]
#
#  - ETA: 4s
# no request id, - ETA: 4s
#
#
# no request id,
#
#  3137536/58889256 [>.............................]
# no request id, 3137536/58889256 [>.............................]
#
#  - ETA: 4s
# no request id, - ETA: 4s
#
#
# no request id,
#
#  3874816/58889256 [>.............................]
# no request id, 3874816/58889256 [>.............................]
#
#  - ETA: 4s
# no request id, - ETA: 4s
#
#
# no request id,
#
#  4661248/58889256 [=>............................]
# no request id, 4661248/58889256 [=>............................]
#
#  - ETA: 4s
# no request id, - ETA: 4s
#
#
# no request id,
#
#  5332992/58889256 [=>............................]
# no request id, 5332992/58889256 [=>............................]
#
#  - ETA: 4s
# no request id, - ETA: 4s
#
#
# no request id,
#
#  6119424/58889256 [==>...........................]
# no request id, 6119424/58889256 [==>...........................]
#
#  - ETA: 4s
# no request id, - ETA: 4s
#
#
# no request id,
#
#  7077888/58889256 [==>...........................]
# no request id, 7077888/58889256 [==>...........................]
#
#  - ETA: 3s
# no request id, - ETA: 3s
#
#
# no request id,
#
#  7806976/58889256 [==>...........................]
# no request id, 7806976/58889256 [==>...........................]
#
#  - ETA: 3s
# no request id, - ETA: 3s
#
#
# no request id,
#
#  8577024/58889256 [===>..........................]
# no request id, 8577024/58889256 [===>..........................]
#
#  - ETA: 3s
# no request id, - ETA: 3s
#
#
# no request id,
#
#  9494528/58889256 [===>..........................]
# no request id, 9494528/58889256 [===>..........................]
#
#  - ETA: 3s
# no request id, - ETA: 3s
#
#
# no request id,
#
# 10313728/58889256 [====>.........................]
# no request id,10313728/58889256 [====>.........................]
#
#  - ETA: 3s
# no request id, - ETA: 3s
#
#
# no request id,
#
# 11182080/58889256 [====>.........................]
# no request id,11182080/58889256 [====>.........................]
#
#  - ETA: 3s
# no request id, - ETA: 3s
#
#
# no request id,
#
# 12230656/58889256 [=====>........................]
# no request id,12230656/58889256 [=====>........................]
#
#  - ETA: 3s
# no request id, - ETA: 3s
#
#
# no request id,
#
# 13123584/58889256 [=====>........................]
# no request id,13123584/58889256 [=====>........................]
#
#  - ETA: 3s
# no request id, - ETA: 3s
#
#
# no request id,
#
# 14180352/58889256 [======>.......................]
# no request id,14180352/58889256 [======>.......................]
#
#  - ETA: 2s
# no request id, - ETA: 2s
#
#
# no request id,
#
# 15015936/58889256 [======>.......................]
# no request id,15015936/58889256 [======>.......................]
#
#  - ETA: 2s
# no request id, - ETA: 2s
#
#
# no request id,
#
# 16179200/58889256 [=======>......................]
# no request id,16179200/58889256 [=======>......................]
#
#  - ETA: 2s
# no request id, - ETA: 2s
#
#
# no request id,
#
# 17391616/58889256 [=======>......................]
# no request id,17391616/58889256 [=======>......................]
#
#  - ETA: 2s
# no request id, - ETA: 2s
#
#
# no request id,
#
# 18423808/58889256 [========>.....................]
# no request id,18423808/58889256 [========>.....................]
#
#  - ETA: 2s
# no request id, - ETA: 2s
#
#
# no request id,
#
# 19537920/58889256 [========>.....................]
# no request id,19537920/58889256 [========>.....................]
#
#  - ETA: 2s
# no request id, - ETA: 2s
#
#
# no request id,
#
# 20750336/58889256 [=========>....................]
# no request id,20750336/58889256 [=========>....................]
#
#  - ETA: 2s
# no request id, - ETA: 2s
#
#
# no request id,
#
# 22110208/58889256 [==========>...................]
# no request id,22110208/58889256 [==========>...................]
#
#  - ETA: 2s
# no request id, - ETA: 2s
#
#
# no request id,
#
# 23306240/58889256 [==========>...................]
# no request id,23306240/58889256 [==========>...................]
#
#  - ETA: 2s
# no request id, - ETA: 2s
#
#
# no request id,
#
# 24436736/58889256 [===========>..................]
# no request id,24436736/58889256 [===========>..................]
#
#  - ETA: 1s
# no request id, - ETA: 1s
#
#
# no request id,
#
# 26189824/58889256 [============>.................]
# no request id,26189824/58889256 [============>.................]
#
#  - ETA: 1s
# no request id, - ETA: 1s
#
#
# no request id,
#
# 27533312/58889256 [=============>................]
# no request id,27533312/58889256 [=============>................]
#
#  - ETA: 1s
# no request id, - ETA: 1s
#
#
# no request id,
#
# 29040640/58889256 [=============>................]
# no request id,29040640/58889256 [=============>................]
#
#  - ETA: 1s
# no request id, - ETA: 1s
#
#
# no request id,
#
# 30416896/58889256 [==============>...............]
# no request id,30416896/58889256 [==============>...............]
#
#  - ETA: 1s
# no request id, - ETA: 1s
#
#
# no request id,
#
# 32038912/58889256 [===============>..............]
# no request id,32038912/58889256 [===============>..............]
#
#  - ETA: 1s
# no request id, - ETA: 1s
#
#
# no request id,
#
# 33660928/58889256 [================>.............]
# no request id,33660928/58889256 [================>.............]
#
#  - ETA: 1s
# no request id, - ETA: 1s
#
#
# no request id,
#
# 35184640/58889256 [================>.............]
# no request id,35184640/58889256 [================>.............]
#
#  - ETA: 1s
# no request id, - ETA: 1s
#
#
# no request id,
#
# 37085184/58889256 [=================>............]
# no request id,37085184/58889256 [=================>............]
#
#  - ETA: 1s
# no request id, - ETA: 1s
#
#
# no request id,
#
# 38739968/58889256 [==================>...........]
# no request id,38739968/58889256 [==================>...........]
#
#  - ETA: 0s
# no request id, - ETA: 0s
#
#
# no request id,
#
# 40460288/58889256 [===================>..........]
# no request id,40460288/58889256 [===================>..........]
#
#  - ETA: 0s
# no request id, - ETA: 0s
#
#
# no request id,
#
# 42377216/58889256 [====================>.........]
# no request id,42377216/58889256 [====================>.........]
#
#  - ETA: 0s
# no request id, - ETA: 0s
#
#
# no request id,
#
# 44179456/58889256 [=====================>........]
# no request id,44179456/58889256 [=====================>........]
#
#  - ETA: 0s
# no request id, - ETA: 0s
#
#
# no request id,
#
# 46063616/58889256 [======================>.......]
# no request id,46063616/58889256 [======================>.......]
#
#  - ETA: 0s
# no request id, - ETA: 0s
#
#
# no request id,
#
# 48168960/58889256 [=======================>......]
# no request id,48168960/58889256 [=======================>......]
#
#  - ETA: 0s
# no request id, - ETA: 0s
#
#
# no request id,
#
# 49537024/58889256 [========================>.....]
# no request id,49537024/58889256 [========================>.....]
#
#  - ETA: 0s
# no request id, - ETA: 0s
#
#
# no request id,
#
# 52518912/58889256 [=========================>....]
# no request id,52518912/58889256 [=========================>....]
#
#  - ETA: 0s
# no request id, - ETA: 0s
#
#
# no request id,
#
# 55255040/58889256 [===========================>..]
# no request id,55255040/58889256 [===========================>..]
#
#  - ETA: 0s
# no request id, - ETA: 0s
#
#
# no request id,
#
# 57458688/58889256 [============================>.]
# no request id,57458688/58889256 [============================>.]
#
#  - ETA: 0s
# no request id, - ETA: 0s
#
#
# no request id,
#
# 58892288/58889256 [==============================]
# no request id,58892288/58889256 [==============================]
#
#  - 2s 0us/step
# no request id, - 2s 0us/step
#
# 2021-06-11 14:40:28,318 | root | INFO | Users's init has completed successfully
# 2021-06-11 14:40:28,320 | root | INFO | Skipping middleware: dbg_model_info as it's not enabled.
# 2021-06-11 14:40:28,320 | root | INFO | Skipping middleware: dbg_resource_usage as it's not enabled.
# 2021-06-11 14:40:28,321 | root | INFO | Scoring timeout is found from os.environ: 60000 ms
# 2021-06-11 14:40:28,331 | root | INFO | Swagger file not present
# 2021-06-11 14:40:28,331 | root | INFO | 404
# 127.0.0.1 - - [11/Jun/2021:14:40:28 +0000] "GET /swagger.json HTTP/1.0" 404 19 "-" "Go-http-client/1.1"
# 2021-06-11 14:40:33,355 | root | INFO | Swagger file not present
# 2021-06-11 14:40:33,355 | root | INFO | 404
# 127.0.0.1 - - [11/Jun/2021:14:40:33 +0000] "GET /swagger.json HTTP/1.0" 404 19 "-" "Go-http-client/1.1"

# %% [markdown]
# ## Appel du web service API

# %%
services = Webservice.list(ws)
print(services[0].scoring_uri)
print(services[0].swagger_uri)
# Out:
# http://0d90bea5-e7a8-4c8d-8787-4307de41b0d4.westeurope.azurecontainer.io/score
# http://0d90bea5-e7a8-4c8d-8787-4307de41b0d4.westeurope.azurecontainer.io/swagger.json

# %%
ARCHITECTURE = 'Unet'
BACKBONE = 'Resnet34' #nobackbone / efficientnetb4 / resnet50
BATCH_SIZE = 128 # 8 / 16 / 32
LR = 0.001
EPOCHS = 100
DIM = (256, 256)
RESIZE = 4 # 2 / 4 / 8
N_CLASSES = 8
N_CHANNELS = 3
ACTIVATION = 'softmax'
LOSS = 'DICE' # CCE / DICE / CCEwDICE
CLASS_WEIGHTS = None

# %%
#map category to its color
def cat2color(arr_to_convert):
    prediction_color = {0:[0, 0, 0],            # void
                        1:[128, 64,128],       # flat
                        2:[150,100,100],         # construction
                        3:[220,220,  0],      # object
                        4:[107,142, 35],       # nature
                        5:[70, 130, 180],       # sky
                        6:[220, 20, 60],        # human
                        7:[119, 11, 32]}          # vehicule
    arr = np.zeros((*arr_to_convert.shape, 3))
    for k, v in prediction_color.items():
        arr[arr_to_convert==k] = v
    arr = arr.astype('uint8')
    return arr

def visualize(**images):
    """PLot images in one row."""
    n = len(images)
    plt.figure(figsize=(16, 5))
    for i, (name, image) in enumerate(images.items()):
        plt.subplot(1, n, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.title(' '.join(name.split('_')).title())
        plt.imshow(image)
    plt.show()

# %%
# helper function for data visualization
def visualize(**images):
    """PLot images in one row."""
    n = len(images)
    plt.figure(figsize=(16, 5))
    for i, (name, image) in enumerate(images.items()):
        plt.subplot(1, n, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.title(' '.join(name.split('_')).title())
        plt.imshow(image)
    plt.show()
    
# helper function for data visualization    
def denormalize(x):
    """Scale image to range 0..1 for correct plot"""
    x_max = np.percentile(x, 98)
    x_min = np.percentile(x, 2)    
    x = (x - x_min) / (x_max - x_min)
    x = x.clip(0, 1)
    return x

# %%
import requests

uri = 'http://0d90bea5-e7a8-4c8d-8787-4307de41b0d4.westeurope.azurecontainer.io/score'
image_path = 'frankfurt_000000_002196_leftImg8bit.png'
files = {'image': open(image_path, 'rb').read()}

response = requests.post(uri, files=files)

print(response.json)
# Out:
# <bound method Response.json of <Response [200]>>

# %%
prediction_array = np.array(response.json())
prediction_array_colored = cat2color(prediction_array)

# %%
tf.keras.preprocessing.image.array_to_img(prediction_array_colored)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x1F3FAB07AC0>

# %%
visualize(predicted_mask=prediction_array)

# %%
import requests

uri = 'http://0d90bea5-e7a8-4c8d-8787-4307de41b0d4.westeurope.azurecontainer.io/score'
image_path = 'aachen_000003_000019_leftImg8bit.png'
files = {'image': open(image_path, 'rb').read()}

response = requests.post(uri, files=files)

print(response.json)
# Out:
# <bound method Response.json of <Response [200]>>

# %%
prediction_array = np.array(response.json())
prediction_array_colored = cat2color(prediction_array)

# %%
prediction_array_colored.shape
# Out:
# (256, 256, 3)

# %%
tf.keras.preprocessing.image.array_to_img(prediction_array_colored)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x1F3ADA71F40>

# %%
visualize(predicted_mask=prediction_array)
